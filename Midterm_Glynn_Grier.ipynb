# %%
import pandas as pd
df= pd.read_csv('amazon_data.csv')
df.shape
# Out:
# (59, 23)

# %%
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   4/1/2019  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   4/1/2019  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   4/1/2019  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   4/4/2019  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   4/5/2019  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN    your_email@gmail.com      4/1/2019
# 1                    NaN    your_email@gmail.com      4/1/2019
# 2                    NaN    your_email@gmail.com      4/1/2019
# 3                    NaN    your_email@gmail.com      4/5/2019
# 4                    NaN    your_email@gmail.com      4/7/2019
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        NaN
# ...

# %%
df= df.fillna(0)
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   4/1/2019  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   4/1/2019  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   4/1/2019  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   4/4/2019  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   4/5/2019  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      4/1/2019
# 1                    0.0    your_email@gmail.com      4/1/2019
# 2                    0.0    your_email@gmail.com      4/1/2019
# 3                    0.0    your_email@gmail.com      4/5/2019
# 4                    0.0    your_email@gmail.com      4/7/2019
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        0.0
# ...

# %%
df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# C:\Users\grier\AppData\Local\Temp\ipykernel_11764\2463331391.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   4/1/2019  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   4/1/2019  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   4/1/2019  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   4/4/2019  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   4/5/2019  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN    your_email@gmail.com      4/1/2019
# 1                    NaN    your_email@gmail.com      4/1/2019
# ...

# %%
df["Total Charged"].sum()
# Out:
# 1777.7300000000002

# %%
df["Total Charged"].mean()
# Out:
# 30.131016949152542

# %%
df["Total Charged"].median()
# Out:
# 15.95

# %%
df["Total Charged"].mode()
# Out:
# 0    12.99
# Name: Total Charged, dtype: float64

# %%
df["Total Charged"].max()
# Out:
# 210.99

# %%
df["Total Charged"].min()
# Out:
# 1.04

# %%
import numpy as np
stdev= sum(df["Total Charged"])/len(df["Total Charged"])
print(stdev)
# Out:
# 30.131016949152542

# %%
df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# C:\Users\grier\AppData\Local\Temp\ipykernel_11764\148570183.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   4/1/2019  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   4/1/2019  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   4/1/2019  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   4/4/2019  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   4/5/2019  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN    your_email@gmail.com      4/1/2019
# 1                    NaN    your_email@gmail.com      4/1/2019
# ...

# %%
df["Tax Charged"].sum()
# Out:
# 52.60999999999999

# %%
df["Tax Charged"].mean()
# Out:
# 0.8916949152542372

# %%
df["Tax Charged"].mode()
# Out:
# 0    0.0
# Name: Tax Charged, dtype: float64

# %%
df["Tax Charged"].median()
# Out:
# 0.0

# %%
df["Tax Charged"].max()
# Out:
# 11.0

# %%
df["Tax Charged"].min()
# Out:
# 0.0

# %%
df.plot.bar(x='Tax Charged', y='Total Charged', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Tax Charged'>

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
import matplotlib.pyplot as plt

# %%
df.plot(x="Order Date", y="Total Charged", figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
pie= df.plot(kind='pie', y= 'Total Charged', figsize= (9,9), labels= None, radius=1.4)

# %%
x= df["Order Date"]
y=df["Total Charged"]
y2=df["Tax Charged"]
plt.plot(x, y, label="Total Charge", color='blue')
plt.plot(x, y2, label = "Tax Charge", color= 'green')
plt.figure(figsize=(20, 10))
plt.show()
